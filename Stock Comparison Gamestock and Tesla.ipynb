# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import yfinance as yf

# %%
gamestop = yf.Ticker('GME')

# %%
tesla = yf.Ticker('TSLA')

# %%
gamestop.info
# Out:
# {'zip': '76051',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 12000,
# ...

# %%
gamestop_data = gamestop.history(period='max')

# %%
gamestop_data.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2002-02-13  6.480514  6.773400  6.413183  6.766666  19054000        0.0
# 2002-02-14  6.850828  6.864294  6.682503  6.733000   2755400        0.0
# 2002-02-15  6.733001  6.749833  6.632006  6.699336   2097400        0.0
# 2002-02-19  6.665671  6.665671  6.312189  6.430017   1852600        0.0
# 2002-02-20  6.463682  6.648839  6.413184  6.648839   1723200        0.0
#
#             Stock Splits
# Date
# 2002-02-13           0.0
# 2002-02-14           0.0
# 2002-02-15           0.0
# 2002-02-19           0.0
# 2002-02-20           0.0

# %%
tesla_data = tesla.history(period='max')

# %%
tesla_data.head()
# Out:
#              Open   High    Low  Close    Volume  Dividends  Stock Splits
# Date
# 2010-06-29  3.800  5.000  3.508  4.778  93831500          0           0.0
# 2010-06-30  5.158  6.084  4.660  4.766  85935500          0           0.0
# 2010-07-01  5.000  5.184  4.054  4.392  41094000          0           0.0
# 2010-07-02  4.600  4.620  3.742  3.840  25699000          0           0.0
# 2010-07-06  4.000  4.000  3.166  3.222  34334500          0           0.0

# %%
gamestop_data.reset_index().plot(x='Date',y='Close',figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import cufflinks as cf
cf.go_offline()
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot,plot
init_notebook_mode(True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
gamestop_data.reset_index().iplot(x='Date',y='Close')
# Out:
# <div>                            <div id="f80c1bdb-e287-4b22-92ab-a8ebdbc717c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
tesla_data.reset_index().plot(x='Date',y='Close',figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gamestop_data.reset_index().iplot(x='Date',y='Close')
# Out:
# <div>                            <div id="13a542d7-09a2-498f-a23c-d2b972ba98b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
gamestop_data['Close']
# Out:
# Date
# 2002-02-13      6.766666
# 2002-02-14      6.733000
# 2002-02-15      6.699336
# 2002-02-19      6.430017
# 2002-02-20      6.648839
#                  ...
# 2022-02-18    121.529999
# 2022-02-22    118.059998
# 2022-02-23    114.870003
# 2022-02-24    124.580002
# 2022-02-25    118.580002
# Name: Close, Length: 5045, dtype: float64

# %%
gamestop_data.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2002-02-13  6.480514  6.773400  6.413183  6.766666  19054000        0.0
# 2002-02-14  6.850828  6.864294  6.682503  6.733000   2755400        0.0
# 2002-02-15  6.733001  6.749833  6.632006  6.699336   2097400        0.0
# 2002-02-19  6.665671  6.665671  6.312189  6.430017   1852600        0.0
# 2002-02-20  6.463682  6.648839  6.413184  6.648839   1723200        0.0
#
#             Stock Splits
# Date
# 2002-02-13           0.0
# 2002-02-14           0.0
# 2002-02-15           0.0
# 2002-02-19           0.0
# 2002-02-20           0.0

# %%
tesla_data.head()
# Out:
#              Open   High    Low  Close    Volume  Dividends  Stock Splits
# Date
# 2010-06-29  3.800  5.000  3.508  4.778  93831500          0           0.0
# 2010-06-30  5.158  6.084  4.660  4.766  85935500          0           0.0
# 2010-07-01  5.000  5.184  4.054  4.392  41094000          0           0.0
# 2010-07-02  4.600  4.620  3.742  3.840  25699000          0           0.0
# 2010-07-06  4.000  4.000  3.166  3.222  34334500          0           0.0

# %%
pd.concat([gamestop_data,tesla_data],keys=['Gamestop','Tesla'],axis=1)
# Out:
#               Gamestop                                                \
#                   Open        High         Low       Close    Volume
# Date
# 2002-02-13    6.480514    6.773400    6.413183    6.766666  19054000
# 2002-02-14    6.850828    6.864294    6.682503    6.733000   2755400
# 2002-02-15    6.733001    6.749833    6.632006    6.699336   2097400
# 2002-02-19    6.665671    6.665671    6.312189    6.430017   1852600
# 2002-02-20    6.463682    6.648839    6.413184    6.648839   1723200
# ...                ...         ...         ...         ...       ...
# 2022-02-18  124.199997  125.650002  118.129997  121.529999   1548800
# 2022-02-22  118.199997  123.330002  114.190002  118.059998   1539100
# 2022-02-23  121.220001  123.360001  114.279999  114.870003   1348300
# 2022-02-24  105.529999  125.709999  104.120003  124.580002   2256200
# 2022-02-25  123.570000  124.970001  116.489998  118.580002   1703600
#
# ...

# %%
data = pd.concat([gamestop_data,tesla_data],keys=['Gamestop','Tesla'],axis=1)

# %%
data['Gamestop']['Close']
# Out:
# Date
# 2002-02-13      6.766666
# 2002-02-14      6.733000
# 2002-02-15      6.699336
# 2002-02-19      6.430017
# 2002-02-20      6.648839
#                  ...
# 2022-02-18    121.529999
# 2022-02-22    118.059998
# 2022-02-23    114.870003
# 2022-02-24    124.580002
# 2022-02-25    118.580002
# Name: Close, Length: 5045, dtype: float64

# %%
data['Tesla']['Close']
# Out:
# Date
# 2002-02-13           NaN
# 2002-02-14           NaN
# 2002-02-15           NaN
# 2002-02-19           NaN
# 2002-02-20           NaN
#                  ...
# 2022-02-18    856.979980
# 2022-02-22    821.530029
# 2022-02-23    764.039978
# 2022-02-24    800.770020
# 2022-02-25    809.869995
# Name: Close, Length: 5045, dtype: float64

# %%
data.columns.names = ['Company','Stock info']

# %%
data
# Out:
# Company       Gamestop                                                \
# Stock info        Open        High         Low       Close    Volume
# Date
# 2002-02-13    6.480514    6.773400    6.413183    6.766666  19054000
# 2002-02-14    6.850828    6.864294    6.682503    6.733000   2755400
# 2002-02-15    6.733001    6.749833    6.632006    6.699336   2097400
# 2002-02-19    6.665671    6.665671    6.312189    6.430017   1852600
# 2002-02-20    6.463682    6.648839    6.413184    6.648839   1723200
# ...                ...         ...         ...         ...       ...
# 2022-02-18  124.199997  125.650002  118.129997  121.529999   1548800
# 2022-02-22  118.199997  123.330002  114.190002  118.059998   1539100
# 2022-02-23  121.220001  123.360001  114.279999  114.870003   1348300
# 2022-02-24  105.529999  125.709999  104.120003  124.580002   2256200
# 2022-02-25  123.570000  124.970001  116.489998  118.580002   1703600
#
# ...

# %%
data.xs(key='Close',axis=1,level='Stock info').max()
# Out:
# Company
# Gamestop     347.510010
# Tesla       1229.910034
# dtype: float64

# %%
data.xs(key='Close',axis=1,level='Stock info').min()
# Out:
# Company
# Gamestop    2.555174
# Tesla       3.160000
# dtype: float64

# %%
data.xs(key='Close',axis=1,level='Stock info').std()
# Out:
# Company
# Gamestop     37.729522
# Tesla       243.833961
# dtype: float64

# %%
data.xs(key='Close',axis=1,level='Stock info').plot(figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>
